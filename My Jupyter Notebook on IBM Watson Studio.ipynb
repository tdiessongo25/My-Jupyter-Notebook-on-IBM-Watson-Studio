# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Thierry Diessongo**
#
# Project Manager

# %% [markdown]
# *I'm passionate about Data Science because of the endless problem solving potential it has*

# %% [markdown]
# ### The following formula tests the gauss theory

# %%
def gauss(n):
    return (n*(n+1))/2
gauss(100) == sum(range(101))
# Out:
# True

# %% [markdown]
# 1. Chicken
# 2. Beef
# 3. Goat
# 4. Lion
# 5. Dog
# 6. Cat
#
# Markdown | Plus | Ugly
# --- | --- | ---
# *Still* | `renders` | **badly**
# 3 | 1 | 2
#
# [www.ibm.com]
